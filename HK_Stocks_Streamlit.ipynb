# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../yfinance_Project/Stock_HK.csv")

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#            Date  Close  High   Low  Open     Volume          Stock
# 0    2025-01-02   0.77  0.80  0.74  0.80   77328000  HAO TIAN INTL
# 1    2025-01-03   0.76  0.77  0.72  0.77   61520000  HAO TIAN INTL
# 2    2025-01-06   0.85  0.88  0.76  0.76  130821495  HAO TIAN INTL
# 3    2025-01-07   0.87  0.88  0.83  0.85   52144000  HAO TIAN INTL
# 4    2025-01-08   0.87  0.89  0.85  0.86   54144000  HAO TIAN INTL
# ...         ...    ...   ...   ...   ...        ...            ...
# 1431 2026-02-02   2.38  2.47  2.36  2.47  616368355    SENSETIME-W
# 1432 2026-02-03   2.41  2.43  2.31  2.42  529031773    SENSETIME-W
# 1433 2026-02-04   2.37  2.41  2.31  2.40  519615060    SENSETIME-W
# 1434 2026-02-05   2.36  2.38  2.29  2.34  416481562    SENSETIME-W
# 1435 2026-02-06   2.34  2.35  2.27  2.30  383929263    SENSETIME-W
#
# [1436 rows x 7 columns]

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
print(df.Stock.unique())
st = input("Enter Stock Name:")
r = df[df.Stock == st]

sb.lineplot(x=r.Date,y=r.Close)
plt.show()
# Out:
# ['HAO TIAN INTL' 'TRACKER FUND' 'GCL TECH' 'XXF' 'PHYNIX' 'SENSETIME-W']
# Enter Stock Name: TRACKER FUND
